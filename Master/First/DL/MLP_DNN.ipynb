# %% [markdown]
# # Lab 1: Deep Neural Network (DNN)

# %% [markdown]
# ## 1.1 Refresh: build a Single Layer Perceptron
# Let's build a single layer perceptron composed by one dense layer.<br>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define the number of inputs 
n_input_nodes = 2


# First define the model 
model = Sequential() # model lets us define a linear stack of network layers.

# define our single fully connected network layer
dense_layer = Dense(n_input_nodes, activation='sigmoid',kernel_initializer="Ones",bias_initializer="Ones")

# Add the dense layer to the model
model.add(dense_layer)

# %% [markdown]
# ## 1.2 Refresh: build a Multilayer perceptron
# Let's build a multilayer perceptron; MLPs are fully connected, each node in one layer connects with a certain weight to every node in the following layer.
#
# Try to build one composed by two hidden dense layer with ReLU activation and one dense output layer(units=1) with sigmoid activation.

# %%
import numpy as np
# Generate dummy data
train_data = np.random.random((1000, 100))
train_labels = np.random.randint(2, size=(1000, 1))
test_data = np.random.random((100, 100))
test_labels = np.random.randint(2, size=(100, 1))

# Build your first model by creating a Sequential object and then adding 3 Dense layers:
units = 32
# Create a Sequential
model = Sequential()
# Add a Dense layer with 32 neurons, with relu as activation function and input dimension equal to the number of features
model.add(Dense(units, activation='relu', input_dim=train_data.shape[1]))
# Add a Dense layer with 32 neurons, with relu as activation function
model.add(Dense(units, activation='relu'))
# To produce the output Add a Dense layer with 1 neurons, with sigmoid as activation function
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])


# Train the model, iterating on the data in batches of 32 samples
# The fit function output is a History object. The history.history attribute is a record of
# training loss values and metrics values at successive epochs, as well as validation loss values 
# and validation metrics values 
history = model.fit(train_data, train_labels, epochs=30, batch_size=32)
_, train_acc = model.evaluate(train_data, train_labels, verbose=1)
_, test_acc = model.evaluate(test_data, test_labels, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4930 - loss: 0.7002
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5250 - loss: 0.6917
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5540 - loss: 0.6867
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5660 - loss: 0.6853
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5920 - loss: 0.6801
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5860 - loss: 0.6788
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5850 - loss: 0.6761
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6050 - loss: 0.6720
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6160 - loss: 0.6673
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6200 - loss: 0.6619
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6120 - loss: 0.6578
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6180 - loss: 0.6566
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6420 - loss: 0.6485
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6600 - loss: 0.6386
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6410 - loss: 0.6318
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6570 - loss: 0.6251
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6780 - loss: 0.6154
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6770 - loss: 0.6090
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6760 - loss: 0.6006
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6970 - loss: 0.5841
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6960 - loss: 0.5817
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7130 - loss: 0.5666
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7190 - loss: 0.5609
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7540 - loss: 0.5421
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7480 - loss: 0.5386
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7710 - loss: 0.5154
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7740 - loss: 0.5003
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7970 - loss: 0.4816
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8080 - loss: 0.4711
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8020 - loss: 0.4566
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8280 - loss: 0.4372
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5200 - loss: 0.8280
# Train: 0.828, Test: 0.520

# %% [markdown]
# # 1.3 Build a Deep Neural Network
# In this section we will:
# *  1.2.1 Import the dataset
# *  1.2.2 Build a model
# *  1.2.3 Train the model
# *  1.2.4 Evaluate the model

# %% [markdown]
# ## 1.3.1 Import the Dataset
# Fashion-MNIST is a dataset of Zalando's article images consisting of a training set of 60,000 examples and a test set of 10,000 examples. <br>
# Each example is a 28×28 grayscale image, associated with a label from 10 classes.<br>
# <img src="https://res.cloudinary.com/practicaldev/image/fetch/s--s6xGmaZX--/c_imagga_scale,f_auto,fl_progressive,h_900,q_auto,w_1600/https://raw.githubusercontent.com/zalandoresearch/fashion-mnist/master/doc/img/fashion-mnist-sprite.png" width="600px"><br>

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

mnist_fashion = tf.keras.datasets.fashion_mnist
(x_learn, y_learn), (x_test, y_test) = mnist_fashion.load_data()

x_learn, x_test = x_learn / 255.0, x_test / 255.0  # normalization
x_train, x_val, y_train, y_val = train_test_split(
    x_learn, y_learn, test_size=0.3, random_state=42
)

num_classes = 10
print(x_train.shape, x_val.shape, x_test.shape)
# Out:
# (42000, 28, 28) (18000, 28, 28) (10000, 28, 28)

# %% [markdown]
# #### Plot some sample from the training set

# %%
import matplotlib.pyplot as plt 

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(6, 6))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ## 1.3.2 Build a Model
#
# A Deep Neural Network is a neural network composed by many layers and consequently it has a deeper structure. The number of layers in the network depends on different factors: for example on the data available, on the complexity of the problem, on the computational power and so on.
# The value produced as output by a neuron is determined by the input the neuron receives and by the activation function. There exists different choices for the activation function. One of the most used is Relu but it depends on the data and on the network architecture.

# %% [markdown]
# #### Build a model with this structure: Flatten+Dense(ReLU)+Dense(ReLU)+Dense(ReLU)+Dense(ReLU)+Dense(softmax)

# %%
from tensorflow.keras.layers import Flatten
# https://keras.io/layers/core/
model = Sequential()
model.add(Flatten())
# Add a Dense layer with 512 neurons, with relu as activation function
model.add(Dense(512, activation='relu'))
# Add a Dense layer with 256 neurons, with relu as activation function
model.add(Dense(256, activation='relu'))
# Add a Dense layer with 128 neurons, with relu as activation function
model.add(Dense(128, activation='relu'))
# Add a Dense layer with 64 neurons, with relu as activation function
model.add(Dense(64, activation='relu'))
# Add a Dense layer with number of neurons equal to the number of classes, with softmax as activation function
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# When we are building a model there are many design choises that we must operate: the choice of a Loss Function, the Metrics and the Optimizer.<br>
#
# **Loss functions** are used to compare the network's predicted output  with the real output, in each pass of the backpropagations algorithm<br>
# Common loss functions are: mean-squared error, cross-entropy, and so on...<br><br>
# **Metrics** are used to evaluate a model; common metrics are precision, recall, accuracy, auc,..<br>
#
# The **Optimizer** determines the update rules of the weights. The performance and update speed may heavily vary from optimizer to optimizer; in choosing an optimizer what's important to consider is the network depth, the type of layers and the type of data.<br>
# The gif below give an idea on how different Optimizers work.<br>
#
# <img src="https://user-images.githubusercontent.com/11681225/49325458-fc785480-f585-11e8-8d2a-9012d6024c6e.gif" width="460px">

# %% [markdown]
# #### Configures the model for training

# %%
# Optimizers    https://www.tensorflow.org/api_docs/python/tf/keras/optimizers
from tensorflow.keras.optimizers import Adam, SGD, Adadelta, Adagrad, Adamax, Nadam, RMSprop

adam   = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
sgd    = SGD(learning_rate=0.001, momentum=0.0, nesterov=False)
adad   = Adadelta(learning_rate=1.0, rho=0.95)
adag   = Adagrad(learning_rate=0.01)
adamax = Adamax(learning_rate=0.002, beta_1=0.9, beta_2=0.999)
nadam  = Nadam(learning_rate=0.002, beta_1=0.9, beta_2=0.999)
rms    = RMSprop(learning_rate=0.001, rho=0.9)

model.compile(
    optimizer=adam,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Compile the model you created before using 
# adam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric
model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 1.3.3 Train the model
# The batch size is a number of samples processed before the model is updated.<br>
# The number of epochs is the number of complete passes through the training dataset.

# %%
batch_size = 128
epochs = 50
# fit your model and save the returned value as "history". 
# Use both the train and validation set 
# Set both properly the batch size value and the epochs value
history = model.fit(
    x_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_val, y_val)
)
# Out:
# Epoch 1/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8061 - loss: 0.5504 - val_accuracy: 0.8438 - val_loss: 0.4363
# Epoch 2/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8601 - loss: 0.3835 - val_accuracy: 0.8607 - val_loss: 0.3789
# Epoch 3/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8738 - loss: 0.3384 - val_accuracy: 0.8743 - val_loss: 0.3540
# Epoch 4/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8855 - loss: 0.3108 - val_accuracy: 0.8804 - val_loss: 0.3320
# Epoch 5/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8899 - loss: 0.2960 - val_accuracy: 0.8806 - val_loss: 0.3303
# Epoch 6/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8965 - loss: 0.2749 - val_accuracy: 0.8794 - val_loss: 0.3394
# Epoch 7/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8997 - loss: 0.2683 - val_accuracy: 0.8750 - val_loss: 0.3452
# Epoch 8/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9045 - loss: 0.2571 - val_accuracy: 0.8883 - val_loss: 0.3160
# Epoch 9/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9083 - loss: 0.2425 - val_accuracy: 0.8799 - val_loss: 0.3376
# Epoch 10/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9107 - loss: 0.2343 - val_accuracy: 0.8912 - val_loss: 0.3125
# Epoch 11/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9152 - loss: 0.2240 - val_accuracy: 0.8922 - val_loss: 0.3097
# Epoch 12/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9187 - loss: 0.2139 - val_accuracy: 0.8912 - val_loss: 0.3164
# Epoch 13/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9201 - loss: 0.2122 - val_accuracy: 0.8893 - val_loss: 0.3319
# Epoch 14/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9216 - loss: 0.2050 - val_accuracy: 0.8832 - val_loss: 0.3650
# Epoch 15/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9238 - loss: 0.1993 - val_accuracy: 0.8916 - val_loss: 0.3322
# Epoch 16/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9296 - loss: 0.1864 - val_accuracy: 0.8904 - val_loss: 0.3382
# Epoch 17/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9286 - loss: 0.1866 - val_accuracy: 0.8858 - val_loss: 0.3748
# Epoch 18/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9331 - loss: 0.1752 - val_accuracy: 0.8873 - val_loss: 0.3407
# Epoch 19/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9363 - loss: 0.1677 - val_accuracy: 0.8900 - val_loss: 0.3650
# Epoch 20/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9355 - loss: 0.1674 - val_accuracy: 0.8944 - val_loss: 0.3418
# Epoch 21/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9385 - loss: 0.1616 - val_accuracy: 0.8934 - val_loss: 0.3487
# Epoch 22/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9419 - loss: 0.1511 - val_accuracy: 0.8807 - val_loss: 0.4386
# Epoch 23/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9403 - loss: 0.1580 - val_accuracy: 0.8910 - val_loss: 0.3601
# Epoch 24/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9426 - loss: 0.1485 - val_accuracy: 0.8917 - val_loss: 0.3974
# Epoch 25/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9450 - loss: 0.1426 - val_accuracy: 0.8879 - val_loss: 0.3879
# Epoch 26/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9475 - loss: 0.1382 - val_accuracy: 0.8879 - val_loss: 0.4095
# Epoch 27/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9493 - loss: 0.1303 - val_accuracy: 0.8947 - val_loss: 0.3763
# Epoch 28/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9519 - loss: 0.1239 - val_accuracy: 0.8993 - val_loss: 0.3831
# Epoch 29/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9514 - loss: 0.1268 - val_accuracy: 0.8937 - val_loss: 0.4008
# Epoch 30/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9530 - loss: 0.1218 - val_accuracy: 0.8919 - val_loss: 0.3935
# Epoch 31/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9556 - loss: 0.1159 - val_accuracy: 0.8939 - val_loss: 0.4116
# Epoch 32/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9530 - loss: 0.1240 - val_accuracy: 0.8900 - val_loss: 0.4437
# Epoch 33/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9547 - loss: 0.1162 - val_accuracy: 0.8931 - val_loss: 0.3715
# Epoch 34/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9594 - loss: 0.1057 - val_accuracy: 0.8977 - val_loss: 0.4129
# Epoch 35/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9605 - loss: 0.1021 - val_accuracy: 0.8970 - val_loss: 0.4349
# Epoch 36/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9605 - loss: 0.1033 - val_accuracy: 0.8917 - val_loss: 0.4387
# Epoch 37/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9579 - loss: 0.1083 - val_accuracy: 0.8935 - val_loss: 0.4330
# Epoch 38/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9623 - loss: 0.0979 - val_accuracy: 0.8921 - val_loss: 0.4668
# Epoch 39/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9650 - loss: 0.0923 - val_accuracy: 0.8949 - val_loss: 0.4728
# Epoch 40/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9640 - loss: 0.0931 - val_accuracy: 0.8894 - val_loss: 0.4725
# Epoch 41/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9664 - loss: 0.0874 - val_accuracy: 0.9003 - val_loss: 0.4655
# Epoch 42/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9678 - loss: 0.0827 - val_accuracy: 0.8960 - val_loss: 0.4306
# Epoch 43/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9690 - loss: 0.0803 - val_accuracy: 0.8982 - val_loss: 0.4940
# Epoch 44/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9675 - loss: 0.0844 - val_accuracy: 0.8939 - val_loss: 0.4551
# Epoch 45/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9687 - loss: 0.0820 - val_accuracy: 0.8949 - val_loss: 0.4689
# Epoch 46/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9708 - loss: 0.0754 - val_accuracy: 0.8947 - val_loss: 0.5043
# Epoch 47/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9722 - loss: 0.0717 - val_accuracy: 0.8981 - val_loss: 0.5603
# Epoch 48/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9718 - loss: 0.0747 - val_accuracy: 0.8908 - val_loss: 0.5651
# Epoch 49/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9716 - loss: 0.0745 - val_accuracy: 0.8913 - val_loss: 0.5022
# Epoch 50/50
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9733 - loss: 0.0695 - val_accuracy: 0.8952 - val_loss: 0.5169

# %% [markdown]
# #### Training history visualization

# %%
def plot_history(history):
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()

# %%
plot_history(history)

# %% [markdown]
# **What could you notice in the loss graph training the model over large number of epochs?**

# %% [markdown]
# ## 1.3.4 Evaluate the model

# %%
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9762 - loss: 0.0630
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8906 - loss: 0.5821
# Train: 0.976, Test: 0.891

# %% [markdown]
# **Try to play with these parameters (loss and optimizers) in order to see how this choice affects the accuracy. What do you expect? which is faster?**

# %% [markdown]
# # 1.4 Dealing with overfitting
# Given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.<br>
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether).<br>
# How to improve generalization of our model on unseen data?<br>
# In this section we will:
# * 1.3.1 Add weight regularization
# * 1.3.2 Dropout
# * 1.3.3 Early stopping

# %% [markdown]
# ## 1.4.1 Add weight regularization
# A common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular".<br>
# This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights.<br> This cost comes in two flavors:
# * L1 regularization
# * L2 regularization
#
# In tf.keras, weight regularization is added by passing weight regularizer instances to layers as keyword arguments.

# %%
from tensorflow.keras import regularizers

# Build the model
model = Sequential()
model.add(Flatten())
# Add a Dense layer with 512 neurons, with relu as activation function and a l2 regularizer (with 0.001 as regularization value) as kernel regularizer 
model.add(Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# Add a Dense layer with 256 neurons, with relu as activation function and a l2 regularizer (with 0.001 as regularization value) as kernel regularizer 
model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# Add a Dense layer with 128 neurons, with relu as activation function and a l2 regularizer (with 0.001 as regularization value) as kernel regularizer 
model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# Add a Dense layer with 64 neurons, with relu as activation function and a l2 regularizer (with 0.001 as regularization value) as kernel regularizer 
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# Add a Dense layer with number of neurons equal to the number of classes, with softmax as activation function
model.add(Dense(num_classes, activation='softmax'))


# Compile the model you just created using 
# adam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric
adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)  
model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


# fit your model and save the returned value as "history". 
# Use both the train and validation set 
# Set both properly the batch size value and the epochs value
batch_size = 128
epochs = 10
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val))

# Call the plot_history function to plot the obtained results
plot_history(history)

# Evaluate
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7964 - loss: 1.2090 - val_accuracy: 0.8349 - val_loss: 0.8875
# Epoch 2/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8457 - loss: 0.7753 - val_accuracy: 0.8291 - val_loss: 0.7561
# Epoch 3/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8555 - loss: 0.6523 - val_accuracy: 0.8581 - val_loss: 0.6267
# Epoch 4/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8627 - loss: 0.5873 - val_accuracy: 0.8676 - val_loss: 0.5651
# Epoch 5/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8659 - loss: 0.5489 - val_accuracy: 0.8476 - val_loss: 0.5946
# Epoch 6/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8708 - loss: 0.5162 - val_accuracy: 0.8582 - val_loss: 0.5392
# Epoch 7/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8729 - loss: 0.4969 - val_accuracy: 0.8677 - val_loss: 0.5093
# Epoch 8/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8745 - loss: 0.4805 - val_accuracy: 0.8762 - val_loss: 0.4809
# Epoch 9/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8771 - loss: 0.4665 - val_accuracy: 0.8759 - val_loss: 0.4775
# Epoch 10/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8806 - loss: 0.4516 - val_accuracy: 0.8657 - val_loss: 0.4939
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8740 - loss: 0.4530
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8492 - loss: 0.5246
# Train: 0.874, Test: 0.849

# %% [markdown]
# ## 1.4.2 Dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks.<br>
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training.<br>
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5; at test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.

# %%
from tensorflow.keras.layers import Dropout
# Build the model
model = Sequential()
model.add(Flatten())
# Add a Dense layer with 512 neurons, with relu as activation function
model.add(Dense(512, activation='relu'))
# Add a Dropout layer with 0.3 drop probability
model.add(Dropout(0.3))
# Add a Dense layer with 256 neurons, with relu as activation function
model.add(Dense(256, activation='relu'))
# Add a Dropout layer with 0.3 drop probability
model.add(Dropout(0.3))
# Add a Dense layer with 128 neurons, with relu as activation function
model.add(Dense(128, activation='relu'))
# Add a Dropout layer with 0.3 drop probability
model.add(Dropout(0.3))
# Add a Dense layer with 64 neurons, with relu as activation function
model.add(Dense(64, activation='relu'))
# Add a Dense layer with number of neurons equal to the number of classes, with softmax as activation function
model.add(Dense(num_classes, activation='softmax'))


# Compile the model you just created using 
# adam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric
adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)  
model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


# fit your model and save the returned value as "history". 
# Use both the train and validation set 
# Set both properly the batch size value and the epochs value
batch_size = 128
epochs = 10
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val))

# Call the plot_history function to plot the obtained results
plot_history(history)

# Evaluate
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.7380 - loss: 0.7191 - val_accuracy: 0.8334 - val_loss: 0.4523
# Epoch 2/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8286 - loss: 0.4751 - val_accuracy: 0.8571 - val_loss: 0.3996
# Epoch 3/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8465 - loss: 0.4223 - val_accuracy: 0.8645 - val_loss: 0.3681
# Epoch 4/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8557 - loss: 0.3976 - val_accuracy: 0.8742 - val_loss: 0.3540
# Epoch 5/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8631 - loss: 0.3763 - val_accuracy: 0.8696 - val_loss: 0.3555
# Epoch 6/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8661 - loss: 0.3639 - val_accuracy: 0.8788 - val_loss: 0.3473
# Epoch 7/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8729 - loss: 0.3504 - val_accuracy: 0.8812 - val_loss: 0.3275
# Epoch 8/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8734 - loss: 0.3390 - val_accuracy: 0.8809 - val_loss: 0.3293
# Epoch 9/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8754 - loss: 0.3380 - val_accuracy: 0.8820 - val_loss: 0.3281
# Epoch 10/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8805 - loss: 0.3244 - val_accuracy: 0.8861 - val_loss: 0.3205
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9025 - loss: 0.2650
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8805 - loss: 0.3495
# Train: 0.902, Test: 0.881

# %% [markdown]
# ## 1.4.3 Early stopping
# Validation can be used to detect when overfitting starts during supervised training of a neural network; training is then stopped before convergence to avoid the overfitting.<br>

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os

# early stopping https://keras.io/callbacks/
es_callback = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# Create checkpoint callback that will save the best model observed during training for later use
checkpoint_path = "checkpoints/cp.weights.h5"  # ← changed from cp.ckpt
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = ModelCheckpoint(checkpoint_path, monitor='val_loss', save_weights_only=True, verbose=1)

# %%
# Build the model
model = Sequential()
model.add(Flatten())
# Add a Dense layer with 512 neurons, with relu as activation function
model.add(Dense(512, activation='relu'))
# Add a Dense layer with 256 neurons, with relu as activation function
model.add(Dense(256, activation='relu'))
# Add a Dense layer with 128 neurons, with relu as activation function
model.add(Dense(128, activation='relu'))
# Add a Dense layer with 64 neurons, with relu as activation function
model.add(Dense(64, activation='relu'))
# Add a Dense layer with number of neurons equal to the number of classes, with softmax as activation function
model.add(Dense(num_classes, activation='softmax'))


# Compile the model you just created using 
# adam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric
adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)  
model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


# fit your model and save the returned value as "history". 
# Use both the train and validation set 
# Set both properly the batch size value and the epochs value
# Be careful to also set properly the callbacks parameter list
batch_size =128
epochs = 10
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val), callbacks=[es_callback, cp_callback])

# Call the plot_history function to plot the obtained results
plot_history(history)

# Evaluate
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/10
# 327/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7330 - loss: 0.7557
# Epoch 1: saving model to checkpoints/cp.weights.h5
#
# Epoch 1: finished saving model to checkpoints/cp.weights.h5
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8022 - loss: 0.5516 - val_accuracy: 0.8494 - val_loss: 0.4128
# Epoch 2/10
# 318/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8541 - loss: 0.4038
# Epoch 2: saving model to checkpoints/cp.weights.h5
#
# Epoch 2: finished saving model to checkpoints/cp.weights.h5
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8590 - loss: 0.3865 - val_accuracy: 0.8657 - val_loss: 0.3831
# Epoch 3/10
# 320/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8738 - loss: 0.3438
# Epoch 3: saving model to checkpoints/cp.weights.h5
#
# Epoch 3: finished saving model to checkpoints/cp.weights.h5
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8737 - loss: 0.3440 - val_accuracy: 0.8689 - val_loss: 0.3590
# Epoch 4/10
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8816 - loss: 0.3161
# Epoch 4: saving model to checkpoints/cp.weights.h5
#
# Epoch 4: finished saving model to checkpoints/cp.weights.h5
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8833 - loss: 0.3113 - val_accuracy: 0.8651 - val_loss: 0.3622
# Epoch 5/10
# 325/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8864 - loss: 0.3030
# Epoch 5: saving model to checkpoints/cp.weights.h5
#
# Epoch 5: finished saving model to checkpoints/cp.weights.h5
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8877 - loss: 0.2975 - val_accuracy: 0.8776 - val_loss: 0.3300
# Epoch 6/10
# 323/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8928 - loss: 0.2834
# Epoch 6: saving model to checkpoints/cp.weights.h5
#
# Epoch 6: finished saving model to checkpoints/cp.weights.h5
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8958 - loss: 0.2801 - val_accuracy: 0.8809 - val_loss: 0.3369
# Epoch 7/10
# 325/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8960 - loss: 0.2743
# Epoch 7: saving model to checkpoints/cp.weights.h5
#
# Epoch 7: finished saving model to checkpoints/cp.weights.h5
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8994 - loss: 0.2692 - val_accuracy: 0.8797 - val_loss: 0.3495
# Epoch 8/10
# 320/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9047 - loss: 0.2547
# Epoch 8: saving model to checkpoints/cp.weights.h5
#
# Epoch 8: finished saving model to checkpoints/cp.weights.h5
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9050 - loss: 0.2527 - val_accuracy: 0.8894 - val_loss: 0.3155
# Epoch 9/10
# 320/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9105 - loss: 0.2365
# Epoch 9: saving model to checkpoints/cp.weights.h5
#
# Epoch 9: finished saving model to checkpoints/cp.weights.h5
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9090 - loss: 0.2422 - val_accuracy: 0.8834 - val_loss: 0.3324
# Epoch 10/10
# 321/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9116 - loss: 0.2367
# Epoch 10: saving model to checkpoints/cp.weights.h5
#
# Epoch 10: finished saving model to checkpoints/cp.weights.h5
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9122 - loss: 0.2374 - val_accuracy: 0.8878 - val_loss: 0.3192
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9188 - loss: 0.2091
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8819 - loss: 0.3459
# Train: 0.919, Test: 0.882

# %% [markdown]
# #### Load weights
# The saved weights can then be loaded and evaluated any time by calling the load_weights() function.

# %%
# This may generate warnings related to saving the state of the optimizer.
# These warnings (and similar warnings throughout this notebook)
# are in place to discourage outdated usage, and can be ignored.
# link https://www.tensorflow.org/tutorials/keras/save_and_restore_models

checkpoint_path = "checkpoints/cp.weights.h5"

model.load_weights(checkpoint_path)

_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9188 - loss: 0.2091
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8819 - loss: 0.3459
# Train: 0.919, Test: 0.882
